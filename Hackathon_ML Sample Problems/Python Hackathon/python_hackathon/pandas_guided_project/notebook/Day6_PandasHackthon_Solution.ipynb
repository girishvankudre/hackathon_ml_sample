# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('excel-comp-data.csv')
df
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
df.isnull().sum()
# Out:
# account        0
# name           0
# street         0
# city           0
# state          0
# postal-code    0
# Jan            0
# Feb            0
# Mar            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
# account        15 non-null int64
# name           15 non-null object
# street         15 non-null object
# city           15 non-null object
# state          15 non-null object
# postal-code    15 non-null int64
# Jan            15 non-null int64
# Feb            15 non-null int64
# Mar            15 non-null int64
# dtypes: int64(5), object(4)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#              account   postal-code            Jan            Feb  \
# count      15.000000     15.000000      15.000000      15.000000
# mean   236509.466667  46400.600000   97466.666667  100466.666667
# std    128420.806565  17343.118919   51159.228558   34450.516618
# min    109996.000000  18008.000000   10000.000000   10000.000000
# 25%    175142.500000  31667.000000   58500.000000   95000.000000
# 50%    212303.000000  46308.000000   91000.000000  120000.000000
# 75%    255561.500000  58123.000000  150000.000000  120000.000000
# max    648336.000000  76517.000000  162000.000000  120000.000000
#
#                  Mar
# count      15.000000
# mean    47800.000000
# std     34996.326338
# min     10000.000000
# 25%     35000.000000
# 50%     35000.000000
# 75%     45000.000000
# max    162000.000000

# %% [markdown]
# # The names of the states state column are changed to lower case and store it in df['state']

# %%
df['state'] = df.apply(lambda x: x['state'].lower(), axis=1)
df
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# ...

# %% [markdown]
# # Create a new column named total which computes the total amount in the first quarter of the financial year i.e. for the months of Jan, Feb and Mar and store it in df['total']

# %%
df.drop(['total'],axis=1,inplace=True)

# %%
df.drop(['toatl'],axis=1,inplace=True)

# %%
df
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# ...

# %%
df['total'] = df['Jan'] + df['Feb'] + df['Mar']
df
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# ...

# %% [markdown]
# # Calculate the sum of amount of all users in the Month of Jan, Feb, March and store it in variable sum_row (Here the sum implies the sum of all the entries in the Jan Column, sum of entries in Feb Column and Grand total stands for the sum of entries in the column total)

# %%
sum_row = {"Jan":df['Jan'].sum(),"Feb":df['Feb'].sum(),"Mar":df['Mar'].sum(),"total":df['total'].sum()}
print (sum_row)
# Out:
# {'Jan': 1462000, 'Feb': 1507000, 'Mar': 717000, 'total': 3686000}

# %% [markdown]
# # Append this computed sum to the DataFrame df_final

# %%
df_final = df.copy()
df_final
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# ...

# %%
df_final.append(sum_row,ignore_index=True)
#df_final = df.append(sum_rows,ignore_index=True)
# Out:
#      account                              name  \
# 0   211829.0        Kerluke, Koepp and Hilpert
# 1   320563.0                    Walter-Trantow
# 2   648336.0        Bashirian, Kunde and Price
# 3   109996.0       D'Amore, Gleichner and Bode
# 4   121213.0                     Bauch-Goldner
# 5   132971.0  Williamson, Schumm and Hettinger
# 6   145068.0                        Casper LLC
# 7   205217.0                  Kovacek-Johnston
# 8   209744.0                    Champlin-Morar
# 9   212303.0                    Gerhold-Maggio
# 10  214098.0       Goodwin, Homenick and Jerde
# 11  231907.0                        Hahn-Moore
# 12  242368.0      Frami, Anderson and Donnelly
# 13  268755.0                       Walsh-Haley
# 14  273274.0                     McDermott PLC
# 15       NaN                               NaN
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# ...

# %% [markdown]
# # Scrapes the url https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations and store it in variable url
# Use module requests to get the url and store it in variable called response
# load the html file in dataframe df1. Note:use pd.read_html(response.content)[0].
# First few rows consists of unclean data. You need to select rows from index 11 till end. Make the values at index 11 as column headers and store it in dataframe df1.

# %%
import requests
url = "https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations"
response = requests.get(url)
read_html = pd.read_html(response.content)[0]
read_html.iloc[11:,]
# Out:
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP)  \
# 11                                            Alabama
# 12                                             Alaska
# 13                                            Arizona
# 14                                           Arkansas
# 15                                         California
# 16                                           Colorado
# 17                                        Connecticut
# ...

# %%
read_html.iloc[11:,].to_csv (r'scraped1.csv', index = None, header=True)

# %%
df3 = pd.read_csv('scraped1.csv')

# %%
df4 = df3.iloc[11:]
df4
# Out:
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP)  \
# 22                                             Hawaii
# 23                                              Idaho
# 24                                           Illinois
# 25                                            Indiana
# 26                                               Iowa
# 27                                             Kansas
# 28                                           Kentucky
# ...

# %% [markdown]
# # Remove space from the column named 'United States of America' and store the result in dataframe called df1['United States of America']

# %%
df4.columns
# Out:
# Index(['Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP)',
# ...

# %%
df4.rename(columns={'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP)':'Unnamed:0',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).1':'United States of America',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).2':'Federal state',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).3':'USUSA840',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).4':'US',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).5':'00',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).6':'Unnamed:6',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).7':'Unnamed:7',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).8':'U.S.',
                   'Codes: ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2) ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2) USPS 2-letter codes used by the United States Postal Service USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations: GPO Older variable-length official US Government Printing Office abbreviations AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).9':'U.S..1'},inplace=True)
df4.columns
# Out:
# Index(['Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP)',
# ...

# %%
df1 = pd.read_csv('scraped.csv')

# %%
df1
# Out:
#     Unnamed: 0           United States of America  \
# 0           12                            Alabama
# 1           13                             Alaska
# 2           14                            Arizona
# 3           15                           Arkansas
# 4           16                         California
# 5           17                           Colorado
# 6           18                        Connecticut
# 7           19                           Delaware
# 8           20                 DistrictofColumbia
# 9           21                            Florida
# 10          22                            Georgia
# 11          23                             Hawaii
# 12          24                              Idaho
# 13          25                           Illinois
# 14          26                            Indiana
# 15          27                               Iowa
# 16          28                             Kansas
# 17          29                           Kentucky
# ...

# %%
df1['United States of America'] = df1.apply(lambda x: x['United States of America'].strip(),axis=1)
df1
# Out:
#     Unnamed: 0           United States of America  \
# 0           12                            Alabama
# 1           13                             Alaska
# 2           14                            Arizona
# 3           15                           Arkansas
# 4           16                         California
# 5           17                           Colorado
# 6           18                        Connecticut
# 7           19                           Delaware
# 8           20                 DistrictofColumbia
# 9           21                            Florida
# 10          22                            Georgia
# 11          23                             Hawaii
# 12          24                              Idaho
# 13          25                           Illinois
# 14          26                            Indiana
# 15          27                               Iowa
# 16          28                             Kansas
# 17          29                           Kentucky
# ...

# %% [markdown]
# # Mapping Countries to their abbreviations
# Using the data scraped from the previous task, map abbriviation to the name of states.
# # Instructions:
# Using the scraped data create a variable called mapping which has the Country as key and Abbreviation as value
# Create a new column called abbr as the 7th column (index = 6) of the DataFrame df_final
# map the df_final['state'] on variable mapping and store it in df_final['abbr']

# %%
df1['United States of America'] = df1.apply(lambda x: x['United States of America'].lower(), axis=1)
df1
# Out:
#     Unnamed: 0           United States of America  \
# 0           12                            alabama
# 1           13                             alaska
# 2           14                            arizona
# 3           15                           arkansas
# 4           16                         california
# 5           17                           colorado
# 6           18                        connecticut
# 7           19                           delaware
# 8           20                 districtofcolumbia
# 9           21                            florida
# 10          22                            georgia
# 11          23                             hawaii
# 12          24                              idaho
# 13          25                           illinois
# 14          26                            indiana
# 15          27                               iowa
# 16          28                             kansas
# 17          29                           kentucky
# ...

# %%
mapping = pd.Series(df1['US'].values,index=df1['United States of America']).to_dict()
print (mapping)
# Out:
# {'alabama': 'AL', 'alaska': 'AK', 'arizona': 'AZ', 'arkansas': 'AR', 'california': 'CA', 'colorado': 'CO', 'connecticut': 'CT', 'delaware': 'DE', 'districtofcolumbia': 'DC', 'florida': 'FL', 'georgia': 'GA', 'hawaii': 'HI', 'idaho': 'ID', 'illinois': 'IL', 'indiana': 'IN', 'iowa': 'IA', 'kansas': 'KS', 'kentucky': 'KY', 'louisiana': 'LA', 'maine': 'ME', 'maryland': 'MD', 'massachusetts': 'MA', 'michigan': 'MI', 'minnesota': 'MN', 'mississippi': 'MS', 'missouri': 'MO', 'montana': 'MT', 'nebraska': nan, 'nevada': 'NV', 'newhampshire': 'NH', 'newjersey': 'NJ', 'newmexico': 'NM', 'newyork': 'NY', 'northcarolina': 'NC', 'northdakota': 'ND', 'ohio': 'OH', 'oklahoma': 'OK', 'oregon': 'OR', 'pennsylvania': 'PA', 'rhodeisland': 'RI', 'southcarolina': 'SC', 'southdakota': 'SD', 'tennessee': 'TN', 'texas': 'TX', 'utah': 'UT', 'vermont': 'VT', 'virginia': 'VA', 'washington': 'WA', 'westvirginia': 'WV', 'wisconsin': 'WI', 'wyoming': 'WY', 'americansamoa': 'AS', 'guam': 'GU', 'northernmarianaislan
# ...

# %%
df_final['abbr'] = df_final['state'].map(mapping)
df_final
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# ...

# %% [markdown]
# # Filling in the Missing Values
# What you will notice in the previous task is that for two states Mississippi and Tennessee will have NaN values in column abbr. In this task you will be filling those missing values manually.
# # Intructions :
# Locate the NaN in the abbr and replace mississipi with MS and store it in df_mississipi
# Locate the NaN in the abbr and replace tenessee with TN and store it in df_tenessee
# update the df_final

# %%
df_final.at[6,'state']
# Out:
# 'mississipi'

# %%
df_final.at[6,'state'] = 'mississipi'

# %%
df_final.at[6,'state']
# Out:
# 'mississipi'

# %%
df_final.at[10,'state'] = 'tenessee'

# %%
df_final.at[10,'state']
# Out:
# 'tenessee'

# %%
df_final.at[6,'state']
# Out:
# 'mississipi'

# %%
df_final.at[6,'abbr']
# Out:
# nan

# %%
df_final.at[6,'abbr'] = 'MS'

# %%
df_final.at[6,'abbr']
# Out:
# 'MS'

# %%
df_final.at[10,'state']
# Out:
# 'tenessee'

# %%
df_final.at[10,'abbr']
# Out:
# nan

# %%
df_final.at[10,'abbr'] = 'TN'

# %%
df_final.at[10,'abbr']
# Out:
# 'TN'

# %%
df_final
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# ...

# %% [markdown]
# # Total amount bank hold
# Here, use the newly created abbr column to understand the total amount that the bank holds in each state. Let us make this data frame more readable by introducing units in this case $ sign representing the unit of mone
#
# #Instructions
#
# > Groups by abbr and finds the sum of aabr,jan,feb ,mar and total store the result in df_sub
# > Write a lambda function to introduce $ sign infromt of all the numbers using applymap and store the result in formatted_df

# %%
df_sub = df_final.groupby('abbr')[['Jan','Feb','Mar']].sum()
df_sub
# Out:
#          Jan     Feb     Mar
# abbr
# AR    150000  120000   35000
# CA    162000  120000   35000
# DE    150000  120000   70000
# IA    253000  240000   70000
# ID     70000  120000   35000
# ME     45000  120000   10000
# MS     62000  120000   70000
# NC     95000   45000   35000
# ND    150000   10000  162000
# PA     70000   95000   35000
# RI    200000  215000   70000
# TN     45000  120000   55000
# TX     10000   62000   35000

# %%
formatted_df = df_sub.applymap(lambda x: '$'+str(x))
formatted_df
# Out:
#           Jan      Feb      Mar
# abbr
# AR    $150000  $120000   $35000
# CA    $162000  $120000   $35000
# DE    $150000  $120000   $70000
# IA    $253000  $240000   $70000
# ID     $70000  $120000   $35000
# ME     $45000  $120000   $10000
# MS     $62000  $120000   $70000
# NC     $95000   $45000   $35000
# ND    $150000   $10000  $162000
# PA     $70000   $95000   $35000
# RI    $200000  $215000   $70000
# TN     $45000  $120000   $55000
# TX     $10000   $62000   $35000

# %% [markdown]
# # Append a row to the DataFrame
# In this task, you will append a row to the data frame which will give us information about the total amount of the various regions in Jan, Feb and march and also the grand total
# # Instructions :
# > Computes the sum of amount of all users in the Month of Jan, Feb, March and the total in variable called sum_row (Here the sum implies the sum of all the entries in the Jan Column, sum of entries in Feb Column and Grand total stands for the sum of entries in the column total)
# > Tranpose the dataframe sum_row and store it in new dataframe df_sub_sum
# > Make sure you append the $ to all the digits and store it in dataframe df_sub_sum .
# > Append this computed sum to the DataFrame final_table
# > rename the index of final_table to  {0: "Total"}

# %%
total_sum = ['$'+str(df_final['Jan'].sum()),'$'+str(df_final['Feb'].sum()),'$'+str(df_final['Mar'].sum()),'$'+str(df_final['total'].sum())]
print (total_sum)
# Out:
# ['$1462000', '$1507000', '$717000', '$3686000']

# %%
sum_row = pd.DataFrame(total_sum,index=['Jan','Feb','Mar','total'], columns=['Amount'])
sum_row
# Out:
#          Amount
# Jan    $1462000
# Feb    $1507000
# Mar     $717000
# total  $3686000

# %%
df_sub_sum = sum_row.transpose()
df_sub_sum
# Out:
#              Jan       Feb      Mar     total
# Amount  $1462000  $1507000  $717000  $3686000

# %%
type(df_sub_sum)
# Out:
# pandas.core.frame.DataFrame

# %%
final_table = df_final.append(df_sub_sum, ignore_index=False, sort=False)
final_table
# Out:
#          account                              name  \
# 0       211829.0        Kerluke, Koepp and Hilpert
# 1       320563.0                    Walter-Trantow
# 2       648336.0        Bashirian, Kunde and Price
# 3       109996.0       D'Amore, Gleichner and Bode
# 4       121213.0                     Bauch-Goldner
# 5       132971.0  Williamson, Schumm and Hettinger
# 6       145068.0                        Casper LLC
# 7       205217.0                  Kovacek-Johnston
# 8       209744.0                    Champlin-Morar
# 9       212303.0                    Gerhold-Maggio
# 10      214098.0       Goodwin, Homenick and Jerde
# 11      231907.0                        Hahn-Moore
# 12      242368.0      Frami, Anderson and Donnelly
# 13      268755.0                       Walsh-Haley
# 14      273274.0                     McDermott PLC
# Amount       NaN                               NaN
#
#                                       street               city  \
# ...

# %%
final_table.rename({0:'Total'})
# Out:
#          account                              name  \
# Total   211829.0        Kerluke, Koepp and Hilpert
# 1       320563.0                    Walter-Trantow
# 2       648336.0        Bashirian, Kunde and Price
# 3       109996.0       D'Amore, Gleichner and Bode
# 4       121213.0                     Bauch-Goldner
# 5       132971.0  Williamson, Schumm and Hettinger
# 6       145068.0                        Casper LLC
# 7       205217.0                  Kovacek-Johnston
# 8       209744.0                    Champlin-Morar
# 9       212303.0                    Gerhold-Maggio
# 10      214098.0       Goodwin, Homenick and Jerde
# 11      231907.0                        Hahn-Moore
# 12      242368.0      Frami, Anderson and Donnelly
# 13      268755.0                       Walsh-Haley
# 14      273274.0                     McDermott PLC
# Amount       NaN                               NaN
#
#                                       street               city  \
# ...

# %% [markdown]
# # Pie chart for total
# Having prepared all the data now its time to present the results visually
# # Instructions :
# add the total of all the three months and store it in variable called df_sub['total']
# plot the pie chart for the df_sub['total']

# %%
df_sub.drop(['total'],axis=1,inplace=True)

# %%
df_sub
# Out:
#          Jan     Feb     Mar
# abbr
# AR    150000  120000   35000
# CA    162000  120000   35000
# DE    150000  120000   70000
# IA    253000  240000   70000
# ID     70000  120000   35000
# ME     45000  120000   10000
# MS     62000  120000   70000
# NC     95000   45000   35000
# ND    150000   10000  162000
# PA     70000   95000   35000
# RI    200000  215000   70000
# TN     45000  120000   55000
# TX     10000   62000   35000

# %%
df_sub['total'] = df_sub.sum(axis=1)

# %%
df_sub
# Out:
#          Jan     Feb     Mar   total
# abbr
# AR    150000  120000   35000  305000
# CA    162000  120000   35000  317000
# DE    150000  120000   70000  340000
# IA    253000  240000   70000  563000
# ID     70000  120000   35000  225000
# ME     45000  120000   10000  175000
# MS     62000  120000   70000  252000
# NC     95000   45000   35000  175000
# ND    150000   10000  162000  322000
# PA     70000   95000   35000  200000
# RI    200000  215000   70000  485000
# TN     45000  120000   55000  220000
# TX     10000   62000   35000  107000

# %%
df_sub.index
# Out:
# Index(['AR', 'CA', 'DE', 'IA', 'ID', 'ME', 'MS', 'NC', 'ND', 'PA', 'RI', 'TN',
#        'TX'],
#       dtype='object', name='abbr')

# %%
df_sub['total']
# Out:
# abbr
# AR    305000
# CA    317000
# DE    340000
# IA    563000
# ID    225000
# ME    175000
# MS    252000
# NC    175000
# ND    322000
# PA    200000
# RI    485000
# TN    220000
# TX    107000
# Name: total, dtype: int64

# %%
# Draw the pie chart
fig = plt.figure(figsize=(15,10))
plt.pie(df_sub['total'],labels=df_sub.index,autopct='%.2f',startangle=90)
plt.axis('equal')
plt.show()
